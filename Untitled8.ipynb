# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/content/deforestation_prediction_dataset.csv")
df.head()
# Out:
#    Rainfall_Index  Temperature  Urban_Expansion  Logging_Activity  \
# 0           37.52        95.08            73.23             59.91
# 1            5.90        86.63            60.15             70.84
# 2           83.26        21.31            18.26             18.42
# 3           43.25        29.19            61.22             14.04
# 4           45.66        78.54            20.05             51.47
#
#    Agriculture_Expansion  Deforestation_Rate
# 0                  15.69               15.68
# 1                   2.16               96.99
# 2                  30.49               52.52
# 3                  29.29               36.70
# 4                  59.28                4.74

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 6 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Rainfall_Index         1000 non-null   float64
#  1   Temperature            1000 non-null   float64
#  2   Urban_Expansion        1000 non-null   float64
#  3   Logging_Activity       1000 non-null   float64
#  4   Agriculture_Expansion  1000 non-null   float64
#  5   Deforestation_Rate     1000 non-null   float64
# dtypes: float64(6)
# memory usage: 47.0 KB

# %%
df.describe()
# Out:
#        Rainfall_Index  Temperature  Urban_Expansion  Logging_Activity  \
# count     1000.000000  1000.000000      1000.000000       1000.000000
# mean        50.254630    48.690010        48.117870         51.485750
# std         28.743593    29.354564        28.977164         28.427481
# min          0.110000     0.210000         0.170000          0.120000
# 25%         25.227500    23.735000        22.577500         27.295000
# 50%         52.185000    48.445000        46.435000         51.620000
# 75%         75.250000    73.832500        72.772500         76.630000
# max         99.940000    99.960000        99.780000         99.970000
#
#        Agriculture_Expansion  Deforestation_Rate
# count            1000.000000         1000.000000
# mean               50.009600           50.006340
# std                29.087858           28.897305
# min                 0.100000            0.100000
# 25%                24.267500           25.552500
# 50%                49.915000           50.315000
# 75%                75.800000           73.822500
# max                99.940000           99.770000

# %%
df.isnull().sum()
# Out:
# Rainfall_Index           0
# Temperature              0
# Urban_Expansion          0
# Logging_Activity         0
# Agriculture_Expansion    0
# Deforestation_Rate       0
# dtype: int64

# %%
sns.histplot(df["Deforestation_Rate"])
plt.plot()
# Out:
# []

# %%
x = df.drop(columns=["Deforestation_Rate"])
y = df["Deforestation_Rate"]

# %%
from sklearn.model_selection import train_test_split
xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
xtrain = scaler.fit_transform(xtrain)
xtest = scaler.transform(xtest)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(xtrain, ytrain)
# Out:
# LinearRegression()

# %%
ypred = model.predict(xtest)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
mae = mean_absolute_error(ytest, ypred)
mse = mean_squared_error(ytest, ypred)
r2 = r2_score(ytest, ypred)

# %%
print("Mean Absolute Error:", mae)
print("Mean Squared Error:", mse)
print("R-squared Score:", r2)
# Out:
# Mean Absolute Error: 27.04084691183731
# Mean Squared Error: 965.0012448172935
# R-squared Score: -0.027328051248487695
